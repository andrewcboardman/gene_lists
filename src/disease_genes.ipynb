# %%
import pandas as pd

# %%
gpcr_genetic_diseases = pd.read_csv('../data/genetic_diseases/Schoeneberg2021_genetic_diseases_by_gpcr.csv')
# Check where this data comes from
gpcr_genetic_diseases = gpcr_genetic_diseases[['HGNC symbol','Functional_effect','Inheritance_pattern']]
gpcr_genetic_diseases.columns = ['HGNC_symbol','action','inheritance']
gpcr_genetic_diseases.to_csv('lists/gpcr_genetic_diseases.csv')
# Out:
#    HGNC_symbol        action          inheritance
# 0       ADGRC1  Inactivating   Autosomal dominant
# 1       ADGRE2    Activating   Autosomal dominant
# 2       ADGRG1  Inactivating  Autosomal recessive
# 3       ADGRG2  Inactivating             X-linked
# 4       ADGRG6  Inactivating  Autosomal recessive
# ..         ...           ...                  ...
# 56       TACR3  Inactivating  Autosomal recessive
# 57      TBXA2R  Inactivating   Autosomal dominant
# 58        TRHR  Inactivating  Autosomal recessive
# 59        TSHR  Inactivating   Autosomal dominant
# 60        TSHR    Activating  Autosomal recessive
#
# [61 rows x 3 columns]
